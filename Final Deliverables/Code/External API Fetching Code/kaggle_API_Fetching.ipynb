# %%
pip install -q kaggle

# %%
# !mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory

# %%
# !kaggle datasets download -d vishnusurya2001/global-sales-data-analytics
# Out:
# ...
#   0% 0.00/3.48M [00:00<?, ?B/s]
# 100% 3.48M/3.48M [00:00<00:00, 214MB/s]

# %%
# !unzip /content/global-sales-data-analytics.zip
# Out:
# Archive:  /content/global-sales-data-analytics.zip
#   inflating: Global_Superstore2.csv
